# %% [markdown]
# # SSD7 Training Tutorial
#
# This tutorial explains how to train an SSD7 on the Udacity road traffic datasets, and just generally how to use this SSD implementation.
#
# Disclaimer about SSD7:
# As you will see below, training SSD7 on the aforementioned datasets yields alright results, but I'd like to emphasize that SSD7 is not a carefully optimized network architecture. The idea was just to build a low-complexity network that is fast (roughly 127 FPS or more than 3 times as fast as SSD300 on a GTX 1070) for testing purposes. Would slightly different anchor box scaling factors or a slightly different number of filters in individual convolution layers make SSD7 significantly better at similar complexity? I don't know, I haven't tried.

# %%
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, TerminateOnNaN, CSVLogger
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd7 import build_model
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms
from data_generator.data_augmentation_chain_variable_input_size import DataAugmentationVariableInputSize
from data_generator.data_augmentation_chain_constant_input_size import DataAugmentationConstantInputSize
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation

# %matplotlib inline

# %% [markdown]
# ## 1. Set the model configuration parameters
#
# The cell below sets a number of parameters that define the model configuration. The parameters set here are being used both by the `build_model()` function that builds the model as well as further down by the constructor for the `SSDInputEncoder` object that is needed to to match ground truth and anchor boxes during the training.
#
# Here are just some comments on a few of the parameters, read the documentation for more details:
#
# * Set the height, width, and number of color channels to whatever you want the model to accept as image input. If your input images have a different size than you define as the model input here, or if your images have non-uniform size, then you must use the data generator's image transformations (resizing and/or cropping) so that your images end up having the required input size before they are fed to the model. to convert your images to the model input size during training. The SSD300 training tutorial uses the same image pre-processing and data augmentation as the original Caffe implementation, so take a look at that to see one possibility of how to deal with non-uniform-size images.
# * The number of classes is the number of positive classes in your dataset, e.g. 20 for Pascal VOC or 80 for MS COCO. Class ID 0 must always be reserved for the background class, i.e. your positive classes must have positive integers as their IDs in your dataset.
# * The `mode` argument in the `build_model()` function determines whether the model will be built with or without a `DecodeDetections` layer as its last layer. In 'training' mode, the model outputs the raw prediction tensor, while in 'inference' and 'inference_fast' modes, the raw predictions are being decoded into absolute coordinates and filtered via confidence thresholding, non-maximum suppression, and top-k filtering. The difference between latter two modes is that 'inference' uses the decoding procedure of the original Caffe implementation, while 'inference_fast' uses a faster, but possibly less accurate decoding procedure.
# * The reason why the list of scaling factors has 5 elements even though there are only 4 predictor layers in tSSD7 is that the last scaling factor is used for the second aspect-ratio-1 box of the last predictor layer. Refer to the documentation for details.
# * `build_model()` and `SSDInputEncoder` have two arguments for the anchor box aspect ratios: `aspect_ratios_global` and `aspect_ratios_per_layer`. You can use either of the two, you don't need to set both. If you use `aspect_ratios_global`, then you pass one list of aspect ratios and these aspect ratios will be used for all predictor layers. Every aspect ratio you want to include must be listed once and only once. If you use `aspect_ratios_per_layer`, then you pass a nested list containing lists of aspect ratios for each individual predictor layer. This is what the SSD300 training tutorial does. It's your design choice whether all predictor layers should use the same aspect ratios or whether you think that for your dataset, certain aspect ratios are only necessary for some predictor layers but not for others. Of course more aspect ratios means more predicted boxes, which in turn means increased computational complexity.
# * If `two_boxes_for_ar1 == True`, then each predictor layer will predict two boxes with aspect ratio one, one a bit smaller, the other one a bit larger.
# * If `clip_boxes == True`, then the anchor boxes will be clipped so that they lie entirely within the image boundaries. It is recommended not to clip the boxes. The anchor boxes form the reference frame for the localization prediction. This reference frame should be the same at every spatial position.
# * In the matching process during the training, the anchor box offsets are being divided by the variances. Leaving them at 1.0 for each of the four box coordinates means that they have no effect. Setting them to less than 1.0 spreads the imagined anchor box offset distribution for the respective box coordinate.
# * `normalize_coords` converts all coordinates from absolute coordinate to coordinates that are relative to the image height and width. This setting has no effect on the outcome of the training.

# %%
img_height = 256 # Height of the input images
img_width = 256 # Width of the input images
img_channels = 3 # Number of color channels of the input images
intensity_mean = 127.5 # Set this to your preference (maybe `None`). The current settings transform the input pixel values to the interval `[-1,1]`.
intensity_range = 127.5 # Set this to your preference (maybe `None`). The current settings transform the input pixel values to the interval `[-1,1]`.
n_classes = 1 # Number of positive classes
scales = [0.08, 0.16] # An explicit list of anchor box scaling factors. If this is passed, it will override `min_scale` and `max_scale`.
aspect_ratios = [1.0] # The list of aspect ratios for the anchor boxes
two_boxes_for_ar1 = True # Whether or not you want to generate two anchor boxes for aspect ratio 1
steps = None # In case you'd like to set the step sizes for the anchor box grids manually; not recommended
offsets = None # In case you'd like to set the offsets for the anchor box grids manually; not recommended
clip_boxes = False # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
variances = [1.0, 1.0, 1.0, 1.0] # The list of variances by which the encoded target coordinates are scaled
normalize_coords = True # Whether or not the model is supposed to use coordinates relative to the image size

# %% [markdown]
# ## 2. Build or load the model
#
# You will want to execute either of the two code cells in the subsequent two sub-sections, not both.

# %% [markdown]
# ### 2.1 Create a new model
#
# If you want to create a new model, this is the relevant section for you. If you want to load a previously saved model, skip ahead to section 2.2.
#
# The code cell below does the following things:
# 1. It calls the function `build_model()` to build the model.
# 2. It optionally loads some weights into the model.
# 3. It then compiles the model for the training. In order to do so, we're defining an optimizer (Adam) and a loss function (SSDLoss) to be passed to the `compile()` method.
#
# `SSDLoss` is a custom Keras loss function that implements the multi-task log loss for classification and smooth L1 loss for localization. `neg_pos_ratio` and `alpha` are set as in the paper.

# %%
# 1: Build the Keras model

K.clear_session() # Clear previous models from memory.

model = build_model(image_size=(img_height, img_width, img_channels),
                    n_classes=n_classes,
                    mode='training',
                    l2_regularization=0.0005,
                    scales=scales,
                    aspect_ratios_global=aspect_ratios,
                    aspect_ratios_per_layer=None,
                    two_boxes_for_ar1=two_boxes_for_ar1,
                    steps=steps,
                    offsets=offsets,
                    clip_boxes=clip_boxes,
                    variances=variances,
                    normalize_coords=normalize_coords,
                    subtract_mean=intensity_mean,
                    divide_by_stddev=intensity_range)

# 2: Optional: Load some weights

#model.load_weights('./ssd7_weights.h5', by_name=True)

# 3: Instantiate an Adam optimizer and the SSD loss function and compile the model

adam = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

model.compile(optimizer=adam, loss=ssd_loss.compute_loss)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  identity_layer (Lambda)        (None, 256, 256, 3)  0           ['input_1[0][0]']
#
#  input_mean_normalization (Lamb  (None, 256, 256, 3)  0          ['identity_layer[0][0]']
#  da)
#
#  input_stddev_normalization (La  (None, 256, 256, 3)  0          ['input_mean_normalization[0][0]'
#  mbda)                                                           ]
#
#  conv1 (Conv2D)                 (None, 256, 256, 32  2432        ['input_stddev_normalization[0][0
#                                 )                                ]']
#
#  bn1 (BatchNormalization)       (None, 256, 256, 32  128         ['conv1[0][0]']
#                                 )
#
#  elu1 (ELU)                     (None, 256, 256, 32  0           ['bn1[0][0]']
#                                 )
#
#  pool1 (MaxPooling2D)           (None, 128, 128, 32  0           ['elu1[0][0]']
#                                 )
#
#  conv2 (Conv2D)                 (None, 128, 128, 48  13872       ['pool1[0][0]']
#                                 )
#
#  bn2 (BatchNormalization)       (None, 128, 128, 48  192         ['conv2[0][0]']
#                                 )
#
#  elu2 (ELU)                     (None, 128, 128, 48  0           ['bn2[0][0]']
#                                 )
#
#  pool2 (MaxPooling2D)           (None, 64, 64, 48)   0           ['elu2[0][0]']
#
#  conv3 (Conv2D)                 (None, 64, 64, 64)   27712       ['pool2[0][0]']
#
#  bn3 (BatchNormalization)       (None, 64, 64, 64)   256         ['conv3[0][0]']
#
#  elu3 (ELU)                     (None, 64, 64, 64)   0           ['bn3[0][0]']
#
#  pool3 (MaxPooling2D)           (None, 32, 32, 64)   0           ['elu3[0][0]']
#
#  conv4 (Conv2D)                 (None, 32, 32, 64)   36928       ['pool3[0][0]']
#
#  bn4 (BatchNormalization)       (None, 32, 32, 64)   256         ['conv4[0][0]']
#
#  elu4 (ELU)                     (None, 32, 32, 64)   0           ['bn4[0][0]']
#
#  classes4 (Conv2D)              (None, 32, 32, 4)    2308        ['elu4[0][0]']
#
#  boxes4 (Conv2D)                (None, 32, 32, 8)    4616        ['elu4[0][0]']
#
#  classes4_reshape (Reshape)     (None, 2048, 2)      0           ['classes4[0][0]']
#
#  anchors4 (AnchorBoxes)         (None, 32, 32, 2, 8  0           ['boxes4[0][0]']
#                                 )
#
#  classes_softmax (Activation)   (None, 2048, 2)      0           ['classes4_reshape[0][0]']
#
#  boxes4_reshape (Reshape)       (None, 2048, 4)      0           ['boxes4[0][0]']
#
#  anchors4_reshape (Reshape)     (None, 2048, 8)      0           ['anchors4[0][0]']
#
#  predictions (Concatenate)      (None, 2048, 14)     0           ['classes_softmax[0][0]',
#                                                                   'boxes4_reshape[0][0]',
#                                                                   'anchors4_reshape[0][0]']
#
# ==================================================================================================
# Total params: 88,700
# Trainable params: 88,284
# Non-trainable params: 416
# __________________________________________________________________________________________________

# %% [markdown]
# ### 2.2 Load a saved model
#
# If you have previously created and saved a model and would now like to load it, simply execute the next code cell. The only thing you need to do is to set the path to the saved model HDF5 file that you would like to load.
#
# The SSD model contains custom objects: Neither the loss function, nor the anchor box or detection decoding layer types are contained in the Keras core library, so we need to provide them to the model loader.
#
# This next code cell assumes that you want to load a model that was created in 'training' mode. If you want to load a model that was created in 'inference' or 'inference_fast' mode, you'll have to add the `DecodeDetections` or `DecodeDetectionsFast` layer type to the `custom_objects` dictionary below.

# %%
# TODO: Set the path to the `.h5` file of the model to be loaded.
model_path = 'ssd7.h5'

# We need to create an SSDLoss object in order to pass that to the model loader.
ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

K.clear_session() # Clear previous models from memory.

model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                               'compute_loss': ssd_loss.compute_loss})

# %% [markdown]
# ## 3. Set up the data generators for the training
#
# The code cells below set up data generators for the training and validation datasets to train the model. You will have to set the file paths to your dataset. Depending on the annotations format of your dataset, you might also have to switch from the CSV parser to the XML or JSON parser, or you might have to write a new parser method in the `DataGenerator` class that can handle whatever format your annotations are in. The [README](https://github.com/pierluigiferrari/ssd_keras/blob/master/README.md) of this repository provides a summary of the design of the `DataGenerator`, which should help you in case you need to write a new parser or adapt one of the existing parsers to your needs.
#
# Note that the generator provides two options to speed up the training. By default, it loads the individual images for a batch from disk. This has two disadvantages. First, for compressed image formats like JPG, this is a huge computational waste, because every image needs to be decompressed again and again every time it is being loaded. Second, the images on disk are likely not stored in a contiguous block of memory, which may also slow down the loading process. The first option that `DataGenerator` provides to deal with this is to load the entire dataset into memory, which reduces the access time for any image to a negligible amount, but of course this is only an option if you have enough free memory to hold the whole dataset. As a second option, `DataGenerator` provides the possibility to convert the dataset into a single HDF5 file. This HDF5 file stores the images as uncompressed arrays in a contiguous block of memory, which dramatically speeds up the loading time. It's not as good as having the images in memory, but it's a lot better than the default option of loading them from their compressed JPG state every time they are needed. Of course such an HDF5 dataset may require significantly more disk space than the compressed images. You can later load these HDF5 datasets directly in the constructor.
#
# Set the batch size to to your preference and to what your GPU memory allows, it's not the most important hyperparameter. The Caffe implementation uses a batch size of 32, but smaller batch sizes work fine, too.
#
# The `DataGenerator` itself is fairly generic. I doesn't contain any data augmentation or bounding box encoding logic. Instead, you pass a list of image transformations and an encoder for the bounding boxes in the `transformations` and `label_encoder` arguments of the data generator's `generate()` method, and the data generator will then apply those given transformations and the encoding to the data. Everything here is preset already, but if you'd like to learn more about the data generator and its data augmentation capabilities, take a look at the detailed tutorial in [this](https://github.com/pierluigiferrari/data_generator_object_detection_2d) repository.
#
# The image processing chain defined further down in the object named `data_augmentation_chain` is just one possibility of what a data augmentation pipeline for unform-size images could look like. Feel free to put together other image processing chains, you can use the `DataAugmentationConstantInputSize` class as a template. Or you could use the original SSD data augmentation pipeline by instantiting an `SSDDataAugmentation` object and passing that to the generator instead. This procedure is not exactly efficient, but it evidently produces good results on multiple datasets.
#
# An `SSDInputEncoder` object, `ssd_input_encoder`, is passed to both the training and validation generators. As explained above, it matches the ground truth labels to the model's anchor boxes and encodes the box coordinates into the format that the model needs.

# %% [markdown]
# ### Note:
#
# The example setup below was used to train SSD7 on two road traffic datasets released by [Udacity](https://github.com/udacity/self-driving-car/tree/master/annotations) with around 20,000 images in total and 5 object classes (car, truck, pedestrian, bicyclist, traffic light), although the vast majority of the objects are cars. The original datasets have a constant image size of 1200x1920 RGB. I consolidated the two datasets, removed a few bad samples (although there are probably many more), and resized the images to 300x480 RGB, i.e. to one sixteenth of the original image size. In case you'd like to train a model on the same dataset, you can download the consolidated and resized dataset I used [here](https://drive.google.com/open?id=1tfBFavijh4UTG4cGqIKwhcklLXUDuY0D) (about 900 MB).

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path=None, labels=['ic'])
val_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path=None, labels=['ic'])

# 2: Parse the image and label lists for the training and validation datasets.

# TODO: Set the paths to your dataset here.

# Images
images_dir = '/home/kerem/AOI_Project/ssd_single_feature_map/slef_generated_single_scale/'

# Ground truth
train_labels_filename = '/home/kerem/AOI_Project/ssd_single_feature_map/slef_generated_single_scale/labels_train.csv'
val_labels_filename   = '/home/kerem/AOI_Project/ssd_single_feature_map/slef_generated_single_scale/labels_val.csv'

train_dataset.parse_csv(images_dir=images_dir,
                        labels_filename=train_labels_filename,
                        input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'], # This is the order of the first six columns in the CSV file that contains the labels for your dataset. If your labels are in XML format, maybe the XML parser will be helpful, check the documentation.
                        include_classes='all')

val_dataset.parse_csv(images_dir=images_dir,
                      labels_filename=val_labels_filename,
                      input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'],
                      include_classes='all')

# Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
# speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
# option in the constructor, because in that cas the images are in memory already anyway. If you don't
# want to create HDF5 datasets, comment out the subsequent two function calls.

train_dataset.create_hdf5_dataset(file_path='self_generated_train.h5',
                                  resize=False,
                                  variable_image_size=True,
                                  verbose=True)

val_dataset.create_hdf5_dataset(file_path='self_generated_val.h5',
                                resize=False,
                                variable_image_size=True,
                                verbose=True)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Creating HDF5 dataset: 100%|██████████| 3500/3500 [00:05<00:00, 672.18it/s]
# Creating HDF5 dataset: 100%|██████████| 1500/1500 [00:02<00:00, 709.74it/s]
# Number of images in the training dataset:	  3500
# Number of images in the validation dataset:	  1500

# %%
# 3: Set the batch size.

batch_size = 16

# 4: Define the image processing chain.

data_augmentation_chain = DataAugmentationConstantInputSize(random_brightness=(-48, 48, 0.5),
                                                            random_contrast=(0.5, 1.8, 0.5),
                                                            random_saturation=(0.5, 1.8, 0.5),
                                                            random_hue=(18, 0.5),
                                                            random_flip=0.5,
                                                            random_translate=((0.03,0.5), (0.03,0.5), 0.5),
                                                            random_scale=(0.5, 2.0, 0.5),
                                                            n_trials_max=3,
                                                            clip_boxes=True,
                                                            overlap_criterion='area',
                                                            bounds_box_filter=(0.3, 1.0),
                                                            bounds_validator=(0.5, 1.0),
                                                            n_boxes_min=1,
                                                            background=(0,0,0))

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('classes4').output_shape[1:3]
#                   model.get_layer('classes5').output_shape[1:3],
#                   model.get_layer('classes6').output_shape[1:3],
#                   model.get_layer('classes7').output_shape[1:3]
                  ]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_global=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.3,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.

train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[data_augmentation_chain],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# %% [markdown]
# ## 4. Set the remaining training parameters and train the model
#
# We've already chosen an optimizer and a learning rate and set the batch size above, now let's set the remaining training parameters.
#
# I'll set a few Keras callbacks below, one for early stopping, one to reduce the learning rate if the training stagnates, one to save the best models during the training, and one to continuously stream the training history to a CSV file after every epoch. Logging to a CSV file makes sense, because if we didn't do that, in case the training terminates with an exception at some point or if the kernel of this Jupyter notebook dies for some reason or anything like that happens, we would lose the entire history for the trained epochs. Feel free to add more callbacks if you want TensorBoard summaries or whatever.

# %%
# Define model callbacks.

# TODO: Set the filepath under which you want to save the weights.
model_checkpoint = ModelCheckpoint(filepath='ssd7_epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5',
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=False,
                                   mode='auto',
                                   save_freq="epoch")

csv_logger = CSVLogger(filename='ssd7_training_log.csv',
                       separator=',',
                       append=True)

early_stopping = EarlyStopping(monitor='val_loss',
                               min_delta=0.0,
                               patience=10,
                               verbose=1)

reduce_learning_rate = ReduceLROnPlateau(monitor='val_loss',
                                         factor=0.2,
                                         patience=8,
                                         verbose=1,
                                         min_delta=0.001,
                                         cooldown=0,
                                         min_lr=0.00001)

callbacks = [model_checkpoint,
             csv_logger,
             early_stopping,
             reduce_learning_rate]

# %% [markdown]
# I'll set one epoch to consist of 1,000 training steps I'll arbitrarily set the number of epochs to 20 here. This does not imply that 20,000 training steps is the right number. Depending on the model, the dataset, the learning rate, etc. you might have to train much longer to achieve convergence, or maybe less.
#
# Instead of trying to train a model to convergence in one go, you might want to train only for a few epochs at a time.
#
# In order to only run a partial training and resume smoothly later on, there are a few things you should note:
# 1. Always load the full model if you can, rather than building a new model and loading previously saved weights into it. Optimizers like SGD or Adam keep running averages of past gradient moments internally. If you always save and load full models when resuming a training, then the state of the optimizer is maintained and the training picks up exactly where it left off. If you build a new model and load weights into it, the optimizer is being initialized from scratch, which, especially in the case of Adam, leads to small but unnecessary setbacks every time you resume the training with previously saved weights.
# 2. You should tell `fit_generator()` which epoch to start from, otherwise it will start with epoch 0 every time you resume the training. Set `initial_epoch` to be the next epoch of your training. Note that this parameter is zero-based, i.e. the first epoch is epoch 0. If you had trained for 10 epochs previously and now you'd want to resume the training from there, you'd set `initial_epoch = 10` (since epoch 10 is the eleventh epoch). Furthermore, set `final_epoch` to the last epoch you want to run. To stick with the previous example, if you had trained for 10 epochs previously and now you'd want to train for another 10 epochs, you'd set `initial_epoch = 10` and `final_epoch = 20`.
# 3. Callbacks like `ModelCheckpoint` or `ReduceLROnPlateau` are stateful, so you might want ot save their state somehow if you want to pick up a training exactly where you left off.

# %%
# TODO: Set the epochs to train for.
# If you're resuming a previous training, set `initial_epoch` and `final_epoch` accordingly.
initial_epoch   = 0
final_epoch     = 300
steps_per_epoch = 1000

history = model.fit(train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6455
# Epoch 1: val_loss improved from inf to 0.21577, saving model to ssd7_epoch-01_loss-0.6455_val_loss-0.2158.h5
# 1000/1000 [==============================] - 82s 77ms/step - loss: 0.6455 - val_loss: 0.2158 - lr: 0.0010
# Epoch 2/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2351
# Epoch 2: val_loss improved from 0.21577 to 0.18361, saving model to ssd7_epoch-02_loss-0.2351_val_loss-0.1836.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.2351 - val_loss: 0.1836 - lr: 0.0010
# Epoch 3/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1798
# Epoch 3: val_loss improved from 0.18361 to 0.12451, saving model to ssd7_epoch-03_loss-0.1798_val_loss-0.1245.h5
# 1000/1000 [==============================] - 76s 76ms/step - loss: 0.1798 - val_loss: 0.1245 - lr: 0.0010
# Epoch 4/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1342
# Epoch 4: val_loss improved from 0.12451 to 0.08780, saving model to ssd7_epoch-04_loss-0.1342_val_loss-0.0878.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.1342 - val_loss: 0.0878 - lr: 0.0010
# Epoch 5/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1039
# Epoch 5: val_loss improved from 0.08780 to 0.06177, saving model to ssd7_epoch-05_loss-0.1039_val_loss-0.0618.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.1039 - val_loss: 0.0618 - lr: 0.0010
# Epoch 6/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0782
# Epoch 6: val_loss improved from 0.06177 to 0.04222, saving model to ssd7_epoch-06_loss-0.0782_val_loss-0.0422.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0782 - val_loss: 0.0422 - lr: 0.0010
# Epoch 7/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0683
# Epoch 7: val_loss improved from 0.04222 to 0.03291, saving model to ssd7_epoch-07_loss-0.0683_val_loss-0.0329.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0683 - val_loss: 0.0329 - lr: 0.0010
# Epoch 8/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0591
# Epoch 8: val_loss improved from 0.03291 to 0.03155, saving model to ssd7_epoch-08_loss-0.0591_val_loss-0.0316.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0591 - val_loss: 0.0316 - lr: 0.0010
# Epoch 9/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0576
# Epoch 9: val_loss improved from 0.03155 to 0.03135, saving model to ssd7_epoch-09_loss-0.0576_val_loss-0.0314.h5
# 1000/1000 [==============================] - 77s 78ms/step - loss: 0.0576 - val_loss: 0.0314 - lr: 0.0010
# Epoch 10/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0541
# Epoch 10: val_loss did not improve from 0.03135
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0541 - val_loss: 0.0394 - lr: 0.0010
# Epoch 11/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0486
# Epoch 11: val_loss did not improve from 0.03135
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0486 - val_loss: 0.0425 - lr: 0.0010
# Epoch 12/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0491
# Epoch 12: val_loss improved from 0.03135 to 0.02723, saving model to ssd7_epoch-12_loss-0.0491_val_loss-0.0272.h5
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0491 - val_loss: 0.0272 - lr: 0.0010
# Epoch 13/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0438
# Epoch 13: val_loss improved from 0.02723 to 0.02330, saving model to ssd7_epoch-13_loss-0.0438_val_loss-0.0233.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0438 - val_loss: 0.0233 - lr: 0.0010
# Epoch 14/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0410
# Epoch 14: val_loss improved from 0.02330 to 0.01862, saving model to ssd7_epoch-14_loss-0.0410_val_loss-0.0186.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0410 - val_loss: 0.0186 - lr: 0.0010
# Epoch 15/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0425
# Epoch 15: val_loss improved from 0.01862 to 0.01787, saving model to ssd7_epoch-15_loss-0.0425_val_loss-0.0179.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0425 - val_loss: 0.0179 - lr: 0.0010
# Epoch 16/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0388
# Epoch 16: val_loss did not improve from 0.01787
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0388 - val_loss: 0.0204 - lr: 0.0010
# Epoch 17/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0369
# Epoch 17: val_loss improved from 0.01787 to 0.01630, saving model to ssd7_epoch-17_loss-0.0369_val_loss-0.0163.h5
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0369 - val_loss: 0.0163 - lr: 0.0010
# Epoch 18/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0374
# Epoch 18: val_loss did not improve from 0.01630
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0374 - val_loss: 0.0170 - lr: 0.0010
# Epoch 19/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0387
# Epoch 19: val_loss improved from 0.01630 to 0.01585, saving model to ssd7_epoch-19_loss-0.0387_val_loss-0.0159.h5
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0387 - val_loss: 0.0159 - lr: 0.0010
# Epoch 20/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0373
# Epoch 20: val_loss improved from 0.01585 to 0.01446, saving model to ssd7_epoch-20_loss-0.0373_val_loss-0.0145.h5
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0373 - val_loss: 0.0145 - lr: 0.0010
# Epoch 21/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0346
# Epoch 21: val_loss did not improve from 0.01446
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0346 - val_loss: 0.0158 - lr: 0.0010
# Epoch 22/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0359
# Epoch 22: val_loss did not improve from 0.01446
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0359 - val_loss: 0.0145 - lr: 0.0010
# Epoch 23/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0350
# Epoch 23: val_loss did not improve from 0.01446
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0350 - val_loss: 0.0173 - lr: 0.0010
# Epoch 24/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0346
# Epoch 24: val_loss did not improve from 0.01446
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0346 - val_loss: 0.0156 - lr: 0.0010
# Epoch 25/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0338
# Epoch 25: val_loss improved from 0.01446 to 0.01297, saving model to ssd7_epoch-25_loss-0.0338_val_loss-0.0130.h5
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0338 - val_loss: 0.0130 - lr: 0.0010
# Epoch 26/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0326
# Epoch 26: val_loss improved from 0.01297 to 0.01294, saving model to ssd7_epoch-26_loss-0.0326_val_loss-0.0129.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0326 - val_loss: 0.0129 - lr: 0.0010
# Epoch 27/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0329
# Epoch 27: val_loss did not improve from 0.01294
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0329 - val_loss: 0.0158 - lr: 0.0010
# Epoch 28/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0327
# Epoch 28: val_loss improved from 0.01294 to 0.01284, saving model to ssd7_epoch-28_loss-0.0327_val_loss-0.0128.h5
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0327 - val_loss: 0.0128 - lr: 0.0010
# Epoch 29/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0325
# Epoch 29: val_loss did not improve from 0.01284
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0325 - val_loss: 0.0130 - lr: 0.0010
# Epoch 30/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0330
# Epoch 30: val_loss did not improve from 0.01284
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0330 - val_loss: 0.0170 - lr: 0.0010
# Epoch 31/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0321
# Epoch 31: val_loss improved from 0.01284 to 0.01212, saving model to ssd7_epoch-31_loss-0.0321_val_loss-0.0121.h5
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0321 - val_loss: 0.0121 - lr: 0.0010
# Epoch 32/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0303
# Epoch 32: val_loss did not improve from 0.01212
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0303 - val_loss: 0.0141 - lr: 0.0010
# Epoch 33/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0305
# Epoch 33: val_loss did not improve from 0.01212
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0305 - val_loss: 0.0128 - lr: 0.0010
# Epoch 34/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0242
# Epoch 34: val_loss improved from 0.01212 to 0.01036, saving model to ssd7_epoch-34_loss-0.0242_val_loss-0.0104.h5
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0242 - val_loss: 0.0104 - lr: 2.0000e-04
# Epoch 35/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0221
# Epoch 35: val_loss improved from 0.01036 to 0.00973, saving model to ssd7_epoch-35_loss-0.0221_val_loss-0.0097.h5
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0221 - val_loss: 0.0097 - lr: 2.0000e-04
# Epoch 36/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0221
# Epoch 36: val_loss improved from 0.00973 to 0.00910, saving model to ssd7_epoch-36_loss-0.0221_val_loss-0.0091.h5
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0221 - val_loss: 0.0091 - lr: 2.0000e-04
# Epoch 37/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0216
# Epoch 37: val_loss improved from 0.00910 to 0.00870, saving model to ssd7_epoch-37_loss-0.0216_val_loss-0.0087.h5
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0216 - val_loss: 0.0087 - lr: 2.0000e-04
# Epoch 38/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0211
# Epoch 38: val_loss improved from 0.00870 to 0.00850, saving model to ssd7_epoch-38_loss-0.0211_val_loss-0.0085.h5
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0211 - val_loss: 0.0085 - lr: 2.0000e-04
# Epoch 39/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0212
# Epoch 39: val_loss improved from 0.00850 to 0.00797, saving model to ssd7_epoch-39_loss-0.0212_val_loss-0.0080.h5
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0212 - val_loss: 0.0080 - lr: 2.0000e-04
# Epoch 40/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0215
# Epoch 40: val_loss did not improve from 0.00797
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0215 - val_loss: 0.0082 - lr: 2.0000e-04
# Epoch 41/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0191
# Epoch 41: val_loss improved from 0.00797 to 0.00757, saving model to ssd7_epoch-41_loss-0.0191_val_loss-0.0076.h5
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0191 - val_loss: 0.0076 - lr: 2.0000e-04
# Epoch 42/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0204
# Epoch 42: val_loss improved from 0.00757 to 0.00744, saving model to ssd7_epoch-42_loss-0.0204_val_loss-0.0074.h5
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0204 - val_loss: 0.0074 - lr: 2.0000e-04
# Epoch 43/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0202
# Epoch 43: val_loss improved from 0.00744 to 0.00732, saving model to ssd7_epoch-43_loss-0.0202_val_loss-0.0073.h5
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0202 - val_loss: 0.0073 - lr: 2.0000e-04
# Epoch 44/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0198
# Epoch 44: val_loss improved from 0.00732 to 0.00718, saving model to ssd7_epoch-44_loss-0.0198_val_loss-0.0072.h5
# 1000/1000 [==============================] - 76s 76ms/step - loss: 0.0198 - val_loss: 0.0072 - lr: 2.0000e-04
# Epoch 45/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0187
# Epoch 45: val_loss improved from 0.00718 to 0.00709, saving model to ssd7_epoch-45_loss-0.0187_val_loss-0.0071.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0187 - val_loss: 0.0071 - lr: 2.0000e-04
# Epoch 46/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0179
# Epoch 46: val_loss improved from 0.00709 to 0.00672, saving model to ssd7_epoch-46_loss-0.0179_val_loss-0.0067.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0179 - val_loss: 0.0067 - lr: 2.0000e-04
# Epoch 47/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0190
# Epoch 47: val_loss improved from 0.00672 to 0.00670, saving model to ssd7_epoch-47_loss-0.0190_val_loss-0.0067.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0190 - val_loss: 0.0067 - lr: 2.0000e-04
# Epoch 48/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0186
# Epoch 48: val_loss did not improve from 0.00670
# 1000/1000 [==============================] - 76s 76ms/step - loss: 0.0186 - val_loss: 0.0067 - lr: 2.0000e-04
# Epoch 49/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0189
# Epoch 49: val_loss improved from 0.00670 to 0.00651, saving model to ssd7_epoch-49_loss-0.0189_val_loss-0.0065.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0189 - val_loss: 0.0065 - lr: 2.0000e-04
# Epoch 50/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0182
# Epoch 50: val_loss improved from 0.00651 to 0.00646, saving model to ssd7_epoch-50_loss-0.0182_val_loss-0.0065.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0182 - val_loss: 0.0065 - lr: 2.0000e-04
# Epoch 51/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0186
# Epoch 51: val_loss did not improve from 0.00646
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0186 - val_loss: 0.0068 - lr: 2.0000e-04
# Epoch 52/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0192
# Epoch 52: val_loss improved from 0.00646 to 0.00629, saving model to ssd7_epoch-52_loss-0.0192_val_loss-0.0063.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0192 - val_loss: 0.0063 - lr: 2.0000e-04
# Epoch 53/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0176
# Epoch 53: val_loss did not improve from 0.00629
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0176 - val_loss: 0.0072 - lr: 2.0000e-04
# Epoch 54/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0183
# Epoch 54: val_loss improved from 0.00629 to 0.00614, saving model to ssd7_epoch-54_loss-0.0183_val_loss-0.0061.h5
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0183 - val_loss: 0.0061 - lr: 2.0000e-04
# Epoch 55/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 55: val_loss improved from 0.00614 to 0.00588, saving model to ssd7_epoch-55_loss-0.0164_val_loss-0.0059.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0164 - val_loss: 0.0059 - lr: 4.0000e-05
# Epoch 56/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0171
# Epoch 56: val_loss improved from 0.00588 to 0.00582, saving model to ssd7_epoch-56_loss-0.0171_val_loss-0.0058.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0171 - val_loss: 0.0058 - lr: 4.0000e-05
# Epoch 57/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0160
# Epoch 57: val_loss improved from 0.00582 to 0.00578, saving model to ssd7_epoch-57_loss-0.0160_val_loss-0.0058.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0160 - val_loss: 0.0058 - lr: 4.0000e-05
# Epoch 58/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0160
# Epoch 58: val_loss did not improve from 0.00578
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0160 - val_loss: 0.0059 - lr: 4.0000e-05
# Epoch 59/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 59: val_loss improved from 0.00578 to 0.00573, saving model to ssd7_epoch-59_loss-0.0161_val_loss-0.0057.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0161 - val_loss: 0.0057 - lr: 4.0000e-05
# Epoch 60/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 60: val_loss did not improve from 0.00573
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0162 - val_loss: 0.0057 - lr: 4.0000e-05
# Epoch 61/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0157
# Epoch 61: val_loss did not improve from 0.00573
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0157 - val_loss: 0.0059 - lr: 4.0000e-05
# Epoch 62/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0156
# Epoch 62: val_loss improved from 0.00573 to 0.00569, saving model to ssd7_epoch-62_loss-0.0156_val_loss-0.0057.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0156 - val_loss: 0.0057 - lr: 4.0000e-05
# Epoch 63/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0158
# Epoch 63: val_loss improved from 0.00569 to 0.00553, saving model to ssd7_epoch-63_loss-0.0158_val_loss-0.0055.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0158 - val_loss: 0.0055 - lr: 4.0000e-05
# Epoch 64/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0151
# Epoch 64: val_loss did not improve from 0.00553
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0151 - val_loss: 0.0056 - lr: 4.0000e-05
# Epoch 65/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0154
# Epoch 65: val_loss did not improve from 0.00553
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0154 - val_loss: 0.0056 - lr: 4.0000e-05
# Epoch 66/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0147
# Epoch 66: val_loss did not improve from 0.00553
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0147 - val_loss: 0.0055 - lr: 4.0000e-05
# Epoch 67/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0150
# Epoch 67: val_loss improved from 0.00553 to 0.00545, saving model to ssd7_epoch-67_loss-0.0150_val_loss-0.0055.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0150 - val_loss: 0.0055 - lr: 4.0000e-05
# Epoch 68/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0156
# Epoch 68: val_loss did not improve from 0.00545
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0156 - val_loss: 0.0055 - lr: 4.0000e-05
# Epoch 69/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0150
# Epoch 69: val_loss improved from 0.00545 to 0.00540, saving model to ssd7_epoch-69_loss-0.0150_val_loss-0.0054.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0150 - val_loss: 0.0054 - lr: 4.0000e-05
# Epoch 70/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0158
# Epoch 70: val_loss did not improve from 0.00540
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0158 - val_loss: 0.0055 - lr: 4.0000e-05
# Epoch 71/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0155
# Epoch 71: val_loss improved from 0.00540 to 0.00528, saving model to ssd7_epoch-71_loss-0.0155_val_loss-0.0053.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0155 - val_loss: 0.0053 - lr: 1.0000e-05
# Epoch 72/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0150
# Epoch 72: val_loss did not improve from 0.00528
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0150 - val_loss: 0.0053 - lr: 1.0000e-05
# Epoch 73/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0152
# Epoch 73: val_loss improved from 0.00528 to 0.00528, saving model to ssd7_epoch-73_loss-0.0152_val_loss-0.0053.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0152 - val_loss: 0.0053 - lr: 1.0000e-05
# Epoch 74/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0145
# Epoch 74: val_loss improved from 0.00528 to 0.00527, saving model to ssd7_epoch-74_loss-0.0145_val_loss-0.0053.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0145 - val_loss: 0.0053 - lr: 1.0000e-05
# Epoch 75/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0150
# Epoch 75: val_loss improved from 0.00527 to 0.00524, saving model to ssd7_epoch-75_loss-0.0150_val_loss-0.0052.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0150 - val_loss: 0.0052 - lr: 1.0000e-05
# Epoch 76/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0145
# Epoch 76: val_loss improved from 0.00524 to 0.00524, saving model to ssd7_epoch-76_loss-0.0145_val_loss-0.0052.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0145 - val_loss: 0.0052 - lr: 1.0000e-05
# Epoch 77/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0146
# Epoch 77: val_loss did not improve from 0.00524
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0146 - val_loss: 0.0052 - lr: 1.0000e-05
# Epoch 78/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 78: val_loss improved from 0.00524 to 0.00521, saving model to ssd7_epoch-78_loss-0.0140_val_loss-0.0052.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0140 - val_loss: 0.0052 - lr: 1.0000e-05
# Epoch 79/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0149
# Epoch 79: val_loss improved from 0.00521 to 0.00520, saving model to ssd7_epoch-79_loss-0.0149_val_loss-0.0052.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0149 - val_loss: 0.0052 - lr: 1.0000e-05
# Epoch 80/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0142
# Epoch 80: val_loss did not improve from 0.00520
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0142 - val_loss: 0.0052 - lr: 1.0000e-05
# Epoch 81/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0142
# Epoch 81: val_loss improved from 0.00520 to 0.00518, saving model to ssd7_epoch-81_loss-0.0142_val_loss-0.0052.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0142 - val_loss: 0.0052 - lr: 1.0000e-05
# Epoch 82/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0146
# Epoch 82: val_loss did not improve from 0.00518
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0146 - val_loss: 0.0052 - lr: 1.0000e-05
# Epoch 83/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0147
# Epoch 83: val_loss improved from 0.00518 to 0.00517, saving model to ssd7_epoch-83_loss-0.0147_val_loss-0.0052.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0147 - val_loss: 0.0052 - lr: 1.0000e-05
# Epoch 84/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0147
# Epoch 84: val_loss improved from 0.00517 to 0.00516, saving model to ssd7_epoch-84_loss-0.0147_val_loss-0.0052.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0147 - val_loss: 0.0052 - lr: 1.0000e-05
# Epoch 85/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0154
# Epoch 85: val_loss improved from 0.00516 to 0.00516, saving model to ssd7_epoch-85_loss-0.0154_val_loss-0.0052.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0154 - val_loss: 0.0052 - lr: 1.0000e-05
# Epoch 86/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0147
# Epoch 86: val_loss did not improve from 0.00516
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0147 - val_loss: 0.0052 - lr: 1.0000e-05
# Epoch 87/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0148
# Epoch 87: val_loss did not improve from 0.00516
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0148 - val_loss: 0.0052 - lr: 1.0000e-05
# Epoch 88/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0144
# Epoch 88: val_loss improved from 0.00516 to 0.00513, saving model to ssd7_epoch-88_loss-0.0144_val_loss-0.0051.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0144 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 89/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0154
# Epoch 89: val_loss improved from 0.00513 to 0.00511, saving model to ssd7_epoch-89_loss-0.0154_val_loss-0.0051.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0154 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 90/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0143
# Epoch 90: val_loss improved from 0.00511 to 0.00511, saving model to ssd7_epoch-90_loss-0.0143_val_loss-0.0051.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0143 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 91/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 91: val_loss improved from 0.00511 to 0.00510, saving model to ssd7_epoch-91_loss-0.0140_val_loss-0.0051.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0140 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 92/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0145
# Epoch 92: val_loss improved from 0.00510 to 0.00510, saving model to ssd7_epoch-92_loss-0.0145_val_loss-0.0051.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0145 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 93/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0147
# Epoch 93: val_loss improved from 0.00510 to 0.00509, saving model to ssd7_epoch-93_loss-0.0147_val_loss-0.0051.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0147 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 94/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0146
# Epoch 94: val_loss improved from 0.00509 to 0.00509, saving model to ssd7_epoch-94_loss-0.0146_val_loss-0.0051.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0146 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 95/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0146
# Epoch 95: val_loss did not improve from 0.00509
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0146 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 96/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0145
# Epoch 96: val_loss did not improve from 0.00509
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0145 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 97/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0138
# Epoch 97: val_loss improved from 0.00509 to 0.00505, saving model to ssd7_epoch-97_loss-0.0138_val_loss-0.0051.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0138 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 98/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0145
# Epoch 98: val_loss did not improve from 0.00505
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0145 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 99/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0142
# Epoch 99: val_loss improved from 0.00505 to 0.00504, saving model to ssd7_epoch-99_loss-0.0142_val_loss-0.0050.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0142 - val_loss: 0.0050 - lr: 1.0000e-05
# Epoch 100/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0146
# Epoch 100: val_loss did not improve from 0.00504
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0146 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 101/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0144
# Epoch 101: val_loss improved from 0.00504 to 0.00504, saving model to ssd7_epoch-101_loss-0.0144_val_loss-0.0050.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0144 - val_loss: 0.0050 - lr: 1.0000e-05
# Epoch 102/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0136
# Epoch 102: val_loss improved from 0.00504 to 0.00504, saving model to ssd7_epoch-102_loss-0.0136_val_loss-0.0050.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0136 - val_loss: 0.0050 - lr: 1.0000e-05
# Epoch 103/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0146
# Epoch 103: val_loss improved from 0.00504 to 0.00502, saving model to ssd7_epoch-103_loss-0.0146_val_loss-0.0050.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0146 - val_loss: 0.0050 - lr: 1.0000e-05
# Epoch 104/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0143
# Epoch 104: val_loss did not improve from 0.00502
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0143 - val_loss: 0.0050 - lr: 1.0000e-05
# Epoch 105/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0138
# Epoch 105: val_loss improved from 0.00502 to 0.00500, saving model to ssd7_epoch-105_loss-0.0138_val_loss-0.0050.h5
# 1000/1000 [==============================] - 77s 78ms/step - loss: 0.0138 - val_loss: 0.0050 - lr: 1.0000e-05
# Epoch 106/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 106: val_loss did not improve from 0.00500
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0140 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 107/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0141
# Epoch 107: val_loss improved from 0.00500 to 0.00498, saving model to ssd7_epoch-107_loss-0.0141_val_loss-0.0050.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0141 - val_loss: 0.0050 - lr: 1.0000e-05
# Epoch 108/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0143
# Epoch 108: val_loss did not improve from 0.00498
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0143 - val_loss: 0.0050 - lr: 1.0000e-05
# Epoch 109/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0147
# Epoch 109: val_loss did not improve from 0.00498
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0147 - val_loss: 0.0050 - lr: 1.0000e-05
# Epoch 110/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0142
# Epoch 110: val_loss improved from 0.00498 to 0.00497, saving model to ssd7_epoch-110_loss-0.0142_val_loss-0.0050.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0142 - val_loss: 0.0050 - lr: 1.0000e-05
# Epoch 111/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0142
# Epoch 111: val_loss improved from 0.00497 to 0.00497, saving model to ssd7_epoch-111_loss-0.0142_val_loss-0.0050.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0142 - val_loss: 0.0050 - lr: 1.0000e-05
# Epoch 112/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 112: val_loss did not improve from 0.00497
# 1000/1000 [==============================] - 81s 81ms/step - loss: 0.0140 - val_loss: 0.0050 - lr: 1.0000e-05
# Epoch 113/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0151
# Epoch 113: val_loss improved from 0.00497 to 0.00494, saving model to ssd7_epoch-113_loss-0.0151_val_loss-0.0049.h5
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0151 - val_loss: 0.0049 - lr: 1.0000e-05
# Epoch 114/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0147
# Epoch 114: val_loss did not improve from 0.00494
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0147 - val_loss: 0.0049 - lr: 1.0000e-05
# Epoch 115/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0133
# Epoch 115: val_loss improved from 0.00494 to 0.00493, saving model to ssd7_epoch-115_loss-0.0133_val_loss-0.0049.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0133 - val_loss: 0.0049 - lr: 1.0000e-05
# Epoch 116/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 116: val_loss improved from 0.00493 to 0.00492, saving model to ssd7_epoch-116_loss-0.0140_val_loss-0.0049.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0140 - val_loss: 0.0049 - lr: 1.0000e-05
# Epoch 117/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 117: val_loss did not improve from 0.00492
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0140 - val_loss: 0.0049 - lr: 1.0000e-05
# Epoch 118/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0146
# Epoch 118: val_loss did not improve from 0.00492
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0146 - val_loss: 0.0049 - lr: 1.0000e-05
# Epoch 119/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0143
# Epoch 119: val_loss did not improve from 0.00492
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0143 - val_loss: 0.0049 - lr: 1.0000e-05
# Epoch 120/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0141
# Epoch 120: val_loss improved from 0.00492 to 0.00489, saving model to ssd7_epoch-120_loss-0.0141_val_loss-0.0049.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0141 - val_loss: 0.0049 - lr: 1.0000e-05
# Epoch 121/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0142
# Epoch 121: val_loss did not improve from 0.00489
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0142 - val_loss: 0.0049 - lr: 1.0000e-05
# Epoch 122/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0136
# Epoch 122: val_loss improved from 0.00489 to 0.00488, saving model to ssd7_epoch-122_loss-0.0136_val_loss-0.0049.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0136 - val_loss: 0.0049 - lr: 1.0000e-05
# Epoch 123/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0147
# Epoch 123: val_loss did not improve from 0.00488
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0147 - val_loss: 0.0049 - lr: 1.0000e-05
# Epoch 124/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0146
# Epoch 124: val_loss did not improve from 0.00488
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0146 - val_loss: 0.0049 - lr: 1.0000e-05
# Epoch 125/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0142
# Epoch 125: val_loss did not improve from 0.00488
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0142 - val_loss: 0.0049 - lr: 1.0000e-05
# Epoch 126/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0135
# Epoch 126: val_loss improved from 0.00488 to 0.00487, saving model to ssd7_epoch-126_loss-0.0135_val_loss-0.0049.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0135 - val_loss: 0.0049 - lr: 1.0000e-05
# Epoch 127/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0135
# Epoch 127: val_loss did not improve from 0.00487
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0135 - val_loss: 0.0049 - lr: 1.0000e-05
# Epoch 128/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0144
# Epoch 128: val_loss improved from 0.00487 to 0.00484, saving model to ssd7_epoch-128_loss-0.0144_val_loss-0.0048.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0144 - val_loss: 0.0048 - lr: 1.0000e-05
# Epoch 129/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0136
# Epoch 129: val_loss improved from 0.00484 to 0.00483, saving model to ssd7_epoch-129_loss-0.0136_val_loss-0.0048.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0136 - val_loss: 0.0048 - lr: 1.0000e-05
# Epoch 130/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0138
# Epoch 130: val_loss did not improve from 0.00483
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0138 - val_loss: 0.0048 - lr: 1.0000e-05
# Epoch 131/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 131: val_loss improved from 0.00483 to 0.00482, saving model to ssd7_epoch-131_loss-0.0140_val_loss-0.0048.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0140 - val_loss: 0.0048 - lr: 1.0000e-05
# Epoch 132/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0143
# Epoch 132: val_loss did not improve from 0.00482
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0143 - val_loss: 0.0048 - lr: 1.0000e-05
# Epoch 133/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0147
# Epoch 133: val_loss improved from 0.00482 to 0.00482, saving model to ssd7_epoch-133_loss-0.0147_val_loss-0.0048.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0147 - val_loss: 0.0048 - lr: 1.0000e-05
# Epoch 134/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0142
# Epoch 134: val_loss improved from 0.00482 to 0.00482, saving model to ssd7_epoch-134_loss-0.0142_val_loss-0.0048.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0142 - val_loss: 0.0048 - lr: 1.0000e-05
# Epoch 135/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0136
# Epoch 135: val_loss improved from 0.00482 to 0.00480, saving model to ssd7_epoch-135_loss-0.0136_val_loss-0.0048.h5
# 1000/1000 [==============================] - 77s 77ms/step - loss: 0.0136 - val_loss: 0.0048 - lr: 1.0000e-05
# Epoch 136/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0136
# Epoch 136: val_loss did not improve from 0.00480
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0136 - val_loss: 0.0049 - lr: 1.0000e-05
# Epoch 137/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0144
# Epoch 137: val_loss improved from 0.00480 to 0.00478, saving model to ssd7_epoch-137_loss-0.0144_val_loss-0.0048.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0144 - val_loss: 0.0048 - lr: 1.0000e-05
# Epoch 138/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 138: val_loss did not improve from 0.00478
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0140 - val_loss: 0.0048 - lr: 1.0000e-05
# Epoch 139/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0136
# Epoch 139: val_loss improved from 0.00478 to 0.00477, saving model to ssd7_epoch-139_loss-0.0136_val_loss-0.0048.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0136 - val_loss: 0.0048 - lr: 1.0000e-05
# Epoch 140/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 140: val_loss did not improve from 0.00477
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0140 - val_loss: 0.0048 - lr: 1.0000e-05
# Epoch 141/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0145
# Epoch 141: val_loss improved from 0.00477 to 0.00476, saving model to ssd7_epoch-141_loss-0.0145_val_loss-0.0048.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0145 - val_loss: 0.0048 - lr: 1.0000e-05
# Epoch 142/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0139
# Epoch 142: val_loss improved from 0.00476 to 0.00475, saving model to ssd7_epoch-142_loss-0.0139_val_loss-0.0048.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0139 - val_loss: 0.0048 - lr: 1.0000e-05
# Epoch 143/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0136
# Epoch 143: val_loss did not improve from 0.00475
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0136 - val_loss: 0.0048 - lr: 1.0000e-05
# Epoch 144/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0136
# Epoch 144: val_loss improved from 0.00475 to 0.00475, saving model to ssd7_epoch-144_loss-0.0136_val_loss-0.0047.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0136 - val_loss: 0.0047 - lr: 1.0000e-05
# Epoch 145/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0143
# Epoch 145: val_loss did not improve from 0.00475
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0143 - val_loss: 0.0048 - lr: 1.0000e-05
# Epoch 146/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0145
# Epoch 146: val_loss did not improve from 0.00475
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0145 - val_loss: 0.0047 - lr: 1.0000e-05
# Epoch 147/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 147: val_loss did not improve from 0.00475
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0140 - val_loss: 0.0048 - lr: 1.0000e-05
# Epoch 148/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0147
# Epoch 148: val_loss did not improve from 0.00475
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0147 - val_loss: 0.0047 - lr: 1.0000e-05
# Epoch 149/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0143
# Epoch 149: val_loss did not improve from 0.00475
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0143 - val_loss: 0.0048 - lr: 1.0000e-05
# Epoch 150/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0130
# Epoch 150: val_loss did not improve from 0.00475
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0130 - val_loss: 0.0048 - lr: 1.0000e-05
# Epoch 151/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0146
# Epoch 151: val_loss improved from 0.00475 to 0.00472, saving model to ssd7_epoch-151_loss-0.0146_val_loss-0.0047.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0146 - val_loss: 0.0047 - lr: 1.0000e-05
# Epoch 152/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0141
# Epoch 152: val_loss improved from 0.00472 to 0.00469, saving model to ssd7_epoch-152_loss-0.0141_val_loss-0.0047.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0141 - val_loss: 0.0047 - lr: 1.0000e-05
# Epoch 153/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0134
# Epoch 153: val_loss improved from 0.00469 to 0.00468, saving model to ssd7_epoch-153_loss-0.0134_val_loss-0.0047.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0134 - val_loss: 0.0047 - lr: 1.0000e-05
# Epoch 154/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0142
# Epoch 154: val_loss did not improve from 0.00468
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0142 - val_loss: 0.0047 - lr: 1.0000e-05
# Epoch 155/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0136
# Epoch 155: val_loss did not improve from 0.00468
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0136 - val_loss: 0.0047 - lr: 1.0000e-05
# Epoch 156/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0146
# Epoch 156: val_loss improved from 0.00468 to 0.00467, saving model to ssd7_epoch-156_loss-0.0146_val_loss-0.0047.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0146 - val_loss: 0.0047 - lr: 1.0000e-05
# Epoch 157/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0144
# Epoch 157: val_loss did not improve from 0.00467
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0144 - val_loss: 0.0047 - lr: 1.0000e-05
# Epoch 158/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 158: val_loss improved from 0.00467 to 0.00465, saving model to ssd7_epoch-158_loss-0.0140_val_loss-0.0046.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0140 - val_loss: 0.0046 - lr: 1.0000e-05
# Epoch 159/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0137
# Epoch 159: val_loss did not improve from 0.00465
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0137 - val_loss: 0.0047 - lr: 1.0000e-05
# Epoch 160/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0145
# Epoch 160: val_loss improved from 0.00465 to 0.00464, saving model to ssd7_epoch-160_loss-0.0145_val_loss-0.0046.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0145 - val_loss: 0.0046 - lr: 1.0000e-05
# Epoch 161/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0137
# Epoch 161: val_loss improved from 0.00464 to 0.00464, saving model to ssd7_epoch-161_loss-0.0137_val_loss-0.0046.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0137 - val_loss: 0.0046 - lr: 1.0000e-05
# Epoch 162/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0134
# Epoch 162: val_loss did not improve from 0.00464
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0134 - val_loss: 0.0046 - lr: 1.0000e-05
# Epoch 163/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0132
# Epoch 163: val_loss improved from 0.00464 to 0.00463, saving model to ssd7_epoch-163_loss-0.0132_val_loss-0.0046.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0132 - val_loss: 0.0046 - lr: 1.0000e-05
# Epoch 164/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0144
# Epoch 164: val_loss improved from 0.00463 to 0.00462, saving model to ssd7_epoch-164_loss-0.0144_val_loss-0.0046.h5
# 1000/1000 [==============================] - 78s 79ms/step - loss: 0.0144 - val_loss: 0.0046 - lr: 1.0000e-05
# Epoch 165/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0132
# Epoch 165: val_loss did not improve from 0.00462
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0132 - val_loss: 0.0046 - lr: 1.0000e-05
# Epoch 166/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0127
# Epoch 166: val_loss did not improve from 0.00462
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0127 - val_loss: 0.0046 - lr: 1.0000e-05
# Epoch 167/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0131
# Epoch 167: val_loss did not improve from 0.00462
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0131 - val_loss: 0.0047 - lr: 1.0000e-05
# Epoch 168/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0138
# Epoch 168: val_loss improved from 0.00462 to 0.00459, saving model to ssd7_epoch-168_loss-0.0138_val_loss-0.0046.h5
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0138 - val_loss: 0.0046 - lr: 1.0000e-05
# Epoch 169/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0147
# Epoch 169: val_loss did not improve from 0.00459
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0147 - val_loss: 0.0046 - lr: 1.0000e-05
# Epoch 170/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0137
# Epoch 170: val_loss did not improve from 0.00459
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0137 - val_loss: 0.0047 - lr: 1.0000e-05
# Epoch 171/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0135
# Epoch 171: val_loss improved from 0.00459 to 0.00459, saving model to ssd7_epoch-171_loss-0.0135_val_loss-0.0046.h5
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0135 - val_loss: 0.0046 - lr: 1.0000e-05
# Epoch 172/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0137
# Epoch 172: val_loss did not improve from 0.00459
# 1000/1000 [==============================] - 78s 78ms/step - loss: 0.0137 - val_loss: 0.0046 - lr: 1.0000e-05
# Epoch 173/300
# ...
# Epoch 242/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0132
# Epoch 242: val_loss did not improve from 0.00425
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0132 - val_loss: 0.0043 - lr: 1.0000e-05
# Epoch 243/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0132
# Epoch 243: val_loss did not improve from 0.00425
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0132 - val_loss: 0.0043 - lr: 1.0000e-05
# Epoch 244/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0134
# Epoch 244: val_loss improved from 0.00425 to 0.00423, saving model to ssd7_epoch-244_loss-0.0134_val_loss-0.0042.h5
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0134 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 245/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0129
# Epoch 245: val_loss did not improve from 0.00423
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0129 - val_loss: 0.0043 - lr: 1.0000e-05
# Epoch 246/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0131
# Epoch 246: val_loss did not improve from 0.00423
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0131 - val_loss: 0.0043 - lr: 1.0000e-05
# Epoch 247/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0133
# Epoch 247: val_loss did not improve from 0.00423
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0133 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 248/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0138
# Epoch 248: val_loss improved from 0.00423 to 0.00423, saving model to ssd7_epoch-248_loss-0.0138_val_loss-0.0042.h5
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0138 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 249/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0136
# Epoch 249: val_loss did not improve from 0.00423
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0136 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 250/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0133
# Epoch 250: val_loss did not improve from 0.00423
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0133 - val_loss: 0.0043 - lr: 1.0000e-05
# Epoch 251/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0133
# Epoch 251: val_loss did not improve from 0.00423
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0133 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 252/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0132
# Epoch 252: val_loss did not improve from 0.00423
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0132 - val_loss: 0.0043 - lr: 1.0000e-05
# Epoch 253/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0131
# Epoch 253: val_loss did not improve from 0.00423
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0131 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 254/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0132
# Epoch 254: val_loss improved from 0.00423 to 0.00422, saving model to ssd7_epoch-254_loss-0.0132_val_loss-0.0042.h5
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0132 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 255/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0132
# Epoch 255: val_loss did not improve from 0.00422
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0132 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 256/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0134
# Epoch 256: val_loss did not improve from 0.00422
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0134 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 257/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0128
# Epoch 257: val_loss improved from 0.00422 to 0.00422, saving model to ssd7_epoch-257_loss-0.0128_val_loss-0.0042.h5
# 1000/1000 [==============================] - 79s 80ms/step - loss: 0.0128 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 258/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0130
# Epoch 258: val_loss improved from 0.00422 to 0.00420, saving model to ssd7_epoch-258_loss-0.0130_val_loss-0.0042.h5
# 1000/1000 [==============================] - 79s 79ms/step - loss: 0.0130 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 259/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0133
# Epoch 259: val_loss improved from 0.00420 to 0.00419, saving model to ssd7_epoch-259_loss-0.0133_val_loss-0.0042.h5
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0133 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 260/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0131
# Epoch 260: val_loss did not improve from 0.00419
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0131 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 261/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0137
# Epoch 261: val_loss improved from 0.00419 to 0.00418, saving model to ssd7_epoch-261_loss-0.0137_val_loss-0.0042.h5
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0137 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 262/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0127
# Epoch 262: val_loss improved from 0.00418 to 0.00418, saving model to ssd7_epoch-262_loss-0.0127_val_loss-0.0042.h5
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0127 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 263/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0131
# Epoch 263: val_loss did not improve from 0.00418
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0131 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 264/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0132
# Epoch 264: val_loss improved from 0.00418 to 0.00418, saving model to ssd7_epoch-264_loss-0.0132_val_loss-0.0042.h5
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0132 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 265/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0129
# Epoch 265: val_loss did not improve from 0.00418
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0129 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 266/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0129
# Epoch 266: val_loss did not improve from 0.00418
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0129 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 267/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0127
# Epoch 267: val_loss improved from 0.00418 to 0.00417, saving model to ssd7_epoch-267_loss-0.0127_val_loss-0.0042.h5
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0127 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 268/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0131
# Epoch 268: val_loss improved from 0.00417 to 0.00416, saving model to ssd7_epoch-268_loss-0.0131_val_loss-0.0042.h5
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0131 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 269/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0127
# Epoch 269: val_loss did not improve from 0.00416
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0127 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 270/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0126
# Epoch 270: val_loss did not improve from 0.00416
# 1000/1000 [==============================] - 81s 81ms/step - loss: 0.0126 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 271/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0130
# Epoch 271: val_loss improved from 0.00416 to 0.00415, saving model to ssd7_epoch-271_loss-0.0130_val_loss-0.0042.h5
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0130 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 272/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0129
# Epoch 272: val_loss did not improve from 0.00415
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0129 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 273/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0126
# Epoch 273: val_loss improved from 0.00415 to 0.00413, saving model to ssd7_epoch-273_loss-0.0126_val_loss-0.0041.h5
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0126 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 274/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0127
# Epoch 274: val_loss did not improve from 0.00413
# 1000/1000 [==============================] - 81s 81ms/step - loss: 0.0127 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 275/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0129
# Epoch 275: val_loss improved from 0.00413 to 0.00412, saving model to ssd7_epoch-275_loss-0.0129_val_loss-0.0041.h5
# 1000/1000 [==============================] - 81s 81ms/step - loss: 0.0129 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 276/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0133
# Epoch 276: val_loss did not improve from 0.00412
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0133 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 277/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0118
# Epoch 277: val_loss did not improve from 0.00412
# 1000/1000 [==============================] - 83s 83ms/step - loss: 0.0118 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 278/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0135
# Epoch 278: val_loss did not improve from 0.00412
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0135 - val_loss: 0.0042 - lr: 1.0000e-05
# Epoch 279/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0131
# Epoch 279: val_loss did not improve from 0.00412
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0131 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 280/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0124
# Epoch 280: val_loss did not improve from 0.00412
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0124 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 281/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0128
# Epoch 281: val_loss did not improve from 0.00412
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0128 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 282/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0130
# Epoch 282: val_loss improved from 0.00412 to 0.00410, saving model to ssd7_epoch-282_loss-0.0130_val_loss-0.0041.h5
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0130 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 283/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0127
# Epoch 283: val_loss did not improve from 0.00410
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0127 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 284/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0126
# Epoch 284: val_loss improved from 0.00410 to 0.00409, saving model to ssd7_epoch-284_loss-0.0126_val_loss-0.0041.h5
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0126 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 285/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0132
# Epoch 285: val_loss did not improve from 0.00409
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0132 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 286/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0134
# Epoch 286: val_loss did not improve from 0.00409
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0134 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 287/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0126
# Epoch 287: val_loss improved from 0.00409 to 0.00408, saving model to ssd7_epoch-287_loss-0.0126_val_loss-0.0041.h5
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0126 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 288/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0126
# Epoch 288: val_loss did not improve from 0.00408
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0126 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 289/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0127
# Epoch 289: val_loss improved from 0.00408 to 0.00407, saving model to ssd7_epoch-289_loss-0.0127_val_loss-0.0041.h5
# 1000/1000 [==============================] - 81s 81ms/step - loss: 0.0127 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 290/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0124
# Epoch 290: val_loss did not improve from 0.00407
# 1000/1000 [==============================] - 80s 81ms/step - loss: 0.0124 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 291/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0129
# Epoch 291: val_loss improved from 0.00407 to 0.00407, saving model to ssd7_epoch-291_loss-0.0129_val_loss-0.0041.h5
# 1000/1000 [==============================] - 80s 80ms/step - loss: 0.0129 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 292/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0123
# Epoch 292: val_loss improved from 0.00407 to 0.00407, saving model to ssd7_epoch-292_loss-0.0123_val_loss-0.0041.h5
# 1000/1000 [==============================] - 81s 81ms/step - loss: 0.0123 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 293/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0131
# Epoch 293: val_loss did not improve from 0.00407
# 1000/1000 [==============================] - 81s 81ms/step - loss: 0.0131 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 294/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0128
# Epoch 294: val_loss improved from 0.00407 to 0.00405, saving model to ssd7_epoch-294_loss-0.0128_val_loss-0.0041.h5
# 1000/1000 [==============================] - 81s 81ms/step - loss: 0.0128 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 295/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0132
# Epoch 295: val_loss did not improve from 0.00405
# 1000/1000 [==============================] - 81s 81ms/step - loss: 0.0132 - val_loss: 0.0041 - lr: 1.0000e-05
# Epoch 296/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0131
# Epoch 296: val_loss improved from 0.00405 to 0.00405, saving model to ssd7_epoch-296_loss-0.0131_val_loss-0.0040.h5
# 1000/1000 [==============================] - 81s 81ms/step - loss: 0.0131 - val_loss: 0.0040 - lr: 1.0000e-05
# Epoch 297/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0131
# Epoch 297: val_loss improved from 0.00405 to 0.00405, saving model to ssd7_epoch-297_loss-0.0131_val_loss-0.0040.h5
# 1000/1000 [==============================] - 81s 81ms/step - loss: 0.0131 - val_loss: 0.0040 - lr: 1.0000e-05
# Epoch 298/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0124
# Epoch 298: val_loss improved from 0.00405 to 0.00404, saving model to ssd7_epoch-298_loss-0.0124_val_loss-0.0040.h5
# 1000/1000 [==============================] - 81s 81ms/step - loss: 0.0124 - val_loss: 0.0040 - lr: 1.0000e-05
# Epoch 299/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0125
# Epoch 299: val_loss improved from 0.00404 to 0.00404, saving model to ssd7_epoch-299_loss-0.0125_val_loss-0.0040.h5
# 1000/1000 [==============================] - 81s 81ms/step - loss: 0.0125 - val_loss: 0.0040 - lr: 1.0000e-05
# Epoch 300/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0126
# Epoch 300: val_loss improved from 0.00404 to 0.00403, saving model to ssd7_epoch-300_loss-0.0126_val_loss-0.0040.h5
# 1000/1000 [==============================] - 81s 81ms/step - loss: 0.0126 - val_loss: 0.0040 - lr: 1.0000e-05

# %% [markdown]
# Let's look at how the training and validation loss evolved to check whether our training is going in the right direction:

# %%
plt.figure(figsize=(20,12))
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc='upper right', prop={'size': 24});

# %% [markdown]
# The validation loss has been decreasing at a similar pace as the training loss, indicating that our model has been learning effectively over the last 30 epochs. We could try to train longer and see if the validation loss can be decreased further. Once the validation loss stops decreasing for a couple of epochs in a row, that's when we will want to stop training. Our final weights will then be the weights of the epoch that had the lowest validation loss.

# %% [markdown]
# ### 5. Make predictions
#
# Now let's make some predictions on the validation dataset with the trained model. For convenience we'll use the validation generator which we've already set up above. Feel free to change the batch size.
#
# You can set the `shuffle` option to `False` if you would like to check the model's progress on the same image(s) over the course of the training.

# %%
# 1: Set the generator for the predictions.

predict_generator = val_dataset.generate(batch_size=20,
                                         shuffle=True,
                                         transformations=[],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'processed_labels',
                                                  'filenames'},
                                         keep_images_without_gt=False)

# %%
# 2: Generate samples

batch_images, batch_labels, batch_filenames = next(predict_generator)

i = 0 # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(batch_labels[i])
# Out:
# Image: /home/kerem/AOI_Project/ssd_single_feature_map/slef_generated_single_scale/PCB_5_20_4831.jpg
#
# Ground truth boxes:
#
# [[  1  31 153  53 175]
#  [  1  57 208  85 236]
#  [  1  63   8  89  34]
#  [  1 130 153 158 181]
#  [  1 162 220 186 244]]

# %%
# 3: Make a prediction

y_pred = model.predict(batch_images)
# Out:
# 1/1 [==============================] - 0s 446ms/step

# %% [markdown]
# Now let's decode the raw predictions in `y_pred`.
#
# Had we created the model in 'inference' or 'inference_fast' mode, then the model's final layer would be a `DecodeDetections` layer and `y_pred` would already contain the decoded predictions, but since we created the model in 'training' mode, the model outputs raw predictions that still need to be decoded and filtered. This is what the `decode_detections()` function is for. It does exactly what the `DecodeDetections` layer would do, but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).
#
# `decode_detections()` with default argument values follows the procedure of the original SSD implementation: First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes, then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45, and out of what is left after that, the top 200 highest confidence boxes are returned. Those settings are for precision-recall scoring purposes though. In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5, since we're only interested in the very confident predictions.

# %%
# 4: Decode the raw prediction `y_pred`

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.5,
                                   iou_threshold=0.45,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded[i])
# Out:
# Predicted boxes:
#
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     1.    63.66   8.44  88.49  33.28]
#  [  1.     1.    30.96 153.06  53.06 175.06]
#  [  1.     1.   129.68 152.49 158.58 181.65]
#  [  1.     1.    57.1  208.05  85.   235.98]
#  [  1.     1.   161.98 220.08 185.97 244.17]]

# %% [markdown]
# Finally, let's draw the predicted boxes onto the image. Each predicted box says its confidence next to the category name. The ground truth boxes are also drawn onto the image in green for comparison.

# %%
# 5: Draw the predicted boxes onto the image
for i in range(len(batch_images)):
    plt.figure(figsize=(20,12))
    plt.imshow(batch_images[i])

    current_axis = plt.gca()

    colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist() # Set the colors for the bounding boxes
    classes = ['background', 'ic'] # Just so we can print class names onto the image instead of IDs

# Draw the ground truth boxes in green (omit the label for more clarity)
    for box in batch_labels[i]:
        xmin = box[1]
        ymin = box[2]
        xmax = box[3]
        ymax = box[4]
        label = '{}'.format(classes[int(box[0])])
        current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='blue', fill=False, linewidth=2))  
        #current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor':'green', 'alpha':1.0})

    # Draw the predicted boxes in blue
    for box in y_pred_decoded[i]:
        xmin = box[-4]
        ymin = box[-3]
        xmax = box[-2]
        ymax = box[-1]
        color = colors[int(box[0])]
        label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
        current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))  
        current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor':color, 'alpha':1.0})
